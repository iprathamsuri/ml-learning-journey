# %%
print("Hello ML")
# Out:
# Hello ML

# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import matplotib.pyplot as plt
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
